# %% [markdown]
# This notebook is part of the Omdena project in Liberia on malaria

# %% [markdown]
# In this notebook, general data exploration has been done. That is the csv files have been loaded and observed. files which need restructuring have been done so using mostly excel. once a file is restructure and can be used for preliminary analysis and eda, it is then saved to the folder "/data/semi clean data" which will be used for further analysis.

# %%
# load required libraries for the eda
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# First load the datasets from the raw data folder

# first dataset: malaria prevalence according to microscopy

df1 = pd.read_csv(r'..\data\raw data\Malaria-Related-cases\Malaria-Related-cases\Predictive Modelling for Malaria Prevention - By Microscpy.csv')

# %%
# display the data in df1

df1.head()
# Out:
#    Country    Survey                           Characteristic  \
# 0  Liberia  2022 MIS       Groups of Counties : Monrovia (L1)
# 1  Liberia  2011 MIS                                 Monrovia
# 2  Liberia  2022 MIS                                    Total
# 3  Liberia  2022 MIS  Groups of Counties : South Central (L1)
# 4  Liberia  2022 MIS  Groups of Counties : North Western (L1)
#
#   Malaria prevalence according to microscopy  Unnamed: 4  \
# 0                        0.7 (CI: 0.0 – 2.1)         NaN
# 1                       7.1 (CI: 3.4 – 10.8)         NaN
# 2                      10.2 (CI: 7.6 – 12.8)         NaN
# 3                      11.3 (CI: 4.9 – 17.6)         NaN
# 4                      11.5 (CI: 8.0 – 15.1)         NaN
#
#                                           Unnamed: 5
# 0                                                NaN
# 1  Percentage of children age 6-59 months tested ...
# 2                                                NaN
# ...

# %% [markdown]
# Observation (changes made)
# - data about counties were extracted to one excel file with three columns: survey(MIS), county, malaria prevalence.
# - data about total prevalence per year was extracted to the 2 page in the same workbook with 2 columns: survey(MIS), malaria prevalence.
# - the workbook is stored in the semi data folder with name "Predictive Modelling for Malaria Prevention - By Microscpy.xlsx"

# %%
# loading the 2nd notebook

df2 = pd.read_csv(r'..\data\raw data\Malaria-Related-cases\Malaria-Related-cases\Predictive Modelling for Malaria Prevention - Malaria Indicator Data.csv')

# %%
# display the data
df2
# Out:
#                                            Unnamed: 0 Liberia Unnamed: 2  \
# 0                                           Indicator    2009       2011
# 1   Households with at least one insecticide-treat...  47.2 %     49.7 %
# 2   Households with at least one insecticide-treat...  11.9 %     16.9 %
# 3   Persons with access to an insecticide-treated ...  25.4 %     30.8 %
# 4   Population who slept under an insecticide-trea...  22.8 %     32.1 %
# 5   Children under 5 who slept under an insecticid...  26.4 %     37.1 %
# 6   Children under 5 who slept under an insecticid...  51.4 %     68.0 %
# 7   Pregnant women who slept under an insecticide-...  32.9 %     39.0 %
# 8   Pregnant women who slept under insecticide-tre...  63.2 %     77.4 %
# 9               SP/Fansidar 3+ doses during pregnancy  11.0 %     26.5 %
# 10  SP/Fansidar 2+ doses, at least one during ANC ...  45.1 %     49.6 %
# 11  Children with fever for whom advice or treatme...  78.3 %     76.6 %
# ...

# %% [markdown]
# Changes made:
# - The data was transposed to have indicators as columns plus year as an additional column

# %%
# loading the third workbook

df3 = pd.read_csv(r'..\data\raw data\Malaria-Related-cases\Malaria-Related-cases\Predictive Modelling for Malaria Prevention - Population denominator for case incidence .csv')

# %%
df3
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1        Year  Population denominator for incidence and morta...      Cases
# 2         NaN                                                NaN      Lower
# 3        2000                                            2895224     784000
# 4        2001                                            2981648     830000
# 5        2002                                            3060599     838000
# 6        2003                                            3085173     843000
# 7        2004                                            3122447     831000
# 8        2005                                            3266318     886000
# 9        2006                                            3455397     956000
# 10       2007                                            3632740    1020000
# ...

# %% [markdown]
# Changes made:
# - data was reformated to have 8 columns: year, Population denominator for incidence and mortality rate,	Cases(lower),	Cases(point),	Cases(upper),	Deaths(lower),	Deaths(point),	Deaths(upper)
# - lower and upper indicate bounds (confidence intervals)

# %%
# read the 4th dataset

df4 = pd.read_csv(r'..\data\raw data\Malaria-Related-cases\Malaria-Related-cases\Predictive Modelling for Malaria Prevention - Rapid Diagnostic Tests (RDTs).csv')

# %%
df4
# Out:
#       Survey                             Characteristic  \
# 0   2022 MIS                                      Total
# 1   2022 MIS                        Age in months : 6-8
# 2   2022 MIS                       Age in months : 9-11
# 3   2022 MIS                      Age in months : 12-17
# 4   2022 MIS                      Age in months : 18-23
# 5   2022 MIS                      Age in months : 24-35
# 6   2022 MIS                      Age in months : 36-47
# 7   2022 MIS                      Age in months : 48-59
# 8   2022 MIS         Groups of Counties : Monrovia (L1)
# 9   2022 MIS    Groups of Counties : North Western (L1)
# 10  2022 MIS    Groups of Counties : South Central (L1)
# 11  2022 MIS  Groups of Counties : South Eastern A (L1)
# 12  2022 MIS  Groups of Counties : South Eastern B (L1)
# 13  2022 MIS    Groups of Counties : North Central (L1)
# 14  2016 MIS                                      Total
# 15  2016 MIS                        Age in months : 6-8
# ...

# %% [markdown]
# Changes made:
# - 3 files were created in an excel workbook
# - 1st file has 4 columns: 	survey (MIS)	age_group(months)	malaria prevalence according to RDT and	CI
# - 2nd file has 4 columns: 	survey (MIS),	counties,	malaria prevalence according to RDT,	CI
# - 3rd file has 3 columns and data for year totals: survey(MIS)	malaria prevalence according to RDT and	CI

# %%
# the 5th dataset

df5 = pd.read_csv(r'..\data\raw data\Malaria-Related-cases\Malaria-Related-cases\Predictive Modelling for Malaria Prevention - Reported Malaria deaths, 2010-2022.csv')

# %%
df5
# Out:
#      Year  2010 2011  2012  2013  2014  2015  2016  2017 2018  2019 2020  \
# 0  Deaths  1422    -  1725  1191  2288  1379  1259   758    -   602    -
#
#    2021  2022
# 0   248   353

# %% [markdown]
# changes:
# - May be simply transposed

# %%
# read the 6th dataset

df6 = pd.read_csv(r'..\data\raw data\Malaria-Related-cases\Malaria-Related-cases\Predictive Modelling for Malaria Prevention - Reported maralia cases by species, 2010-2022.csv')
df6
# Out:
#   Reported maralia cases by species, 2010-2022 Unnamed: 1 Unnamed: 2  \
# 0                                         Year       2010       2011
# 1                                   Indigenous     922173    1921159
# 2                                 P.falciparum     212927     577641
# 3                                      P.vivax          -          -
# 4                                  Mixed cases          0          -
# 5                                  Other cases          0          0
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0       2012       2013       2014       2015       2016       2017
# 1    1412629    1244220     881224     941711    1191137    1093115
# 2    1407455    1244220     864204          -     809356          -
# 3          -          -          -          -          -          -
# 4          -          -          -          0          0          0
# 5          0          0          0          0          0          0
#
# ...

# %% [markdown]
# changes
# - may be simply transposed

# %% [markdown]
# The end.

# %% [markdown]
# Contributor: Ndong Henry
